# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
# Use the citipy module to identify the nearest city to the current coordinate
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | antibes
# Processing Record 2 of Set 1 | mirnyy
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | kahului
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | kavieng
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | pevek
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | henties bay
# Processing Record 13 of Set 1 | clearlake
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | ayan
# Processing Record 17 of Set 1 | roma
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | agirish
# Processing Record 23 of Set 1 | porto novo
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | tailai
# Processing Record 27 of Set 1 | cherskiy
# Processing Record 28 of Set 1 | kupang
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | tazovskiy
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | broome
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | talnakh
# Processing Record 35 of Set 1 | rongcheng
# Processing Record 36 of Set 1 | yulara
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | saint george
# Processing Record 39 of Set 1 | bara
# Processing Record 40 of Set 1 | saleilua
# City not found. Skipping...
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | ahipara
# Processing Record 43 of Set 1 | pisco
# Processing Record 44 of Set 1 | gizo
# Processing Record 45 of Set 1 | oriximina
# Processing Record 46 of Set 1 | namibe
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | jacareacanga
# Processing Record 49 of Set 1 | ciudad bolivar
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | polson
# Processing Record 2 of Set 2 | freeport
# Processing Record 3 of Set 2 | igarka
# Processing Record 4 of Set 2 | bodden town
# Processing Record 5 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | faanui
# Processing Record 8 of Set 2 | narsaq
# Processing Record 9 of Set 2 | bukama
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | jieznas
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | pochutla
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | bama
# Processing Record 19 of Set 2 | paamiut
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | mendeleyevsk
# Processing Record 22 of Set 2 | janauba
# Processing Record 23 of Set 2 | mataura
# Processing Record 24 of Set 2 | hasaki
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | sao filipe
# Processing Record 27 of Set 2 | chicama
# Processing Record 28 of Set 2 | prieska
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | carnarvon
# Processing Record 32 of Set 2 | alpena
# Processing Record 33 of Set 2 | kavaratti
# Processing Record 34 of Set 2 | basco
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | nanortalik
# Processing Record 37 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 2 | norman wells
# Processing Record 39 of Set 2 | fortuna
# Processing Record 40 of Set 2 | cidreira
# Processing Record 41 of Set 2 | belaya gora
# Processing Record 42 of Set 2 | yumen
# Processing Record 43 of Set 2 | ambilobe
# Processing Record 44 of Set 2 | padang
# Processing Record 45 of Set 2 | amahai
# Processing Record 46 of Set 2 | severo-kurilsk
# Processing Record 47 of Set 2 | zhezkazgan
# Processing Record 48 of Set 2 | daru
# Processing Record 49 of Set 2 | pangnirtung
# Processing Record 50 of Set 2 | qaanaaq
# Processing Record 1 of Set 3 | velyka bahachka
# Processing Record 2 of Set 3 | brazzaville
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | katsuura
# Processing Record 5 of Set 3 | anito
# Processing Record 6 of Set 3 | lorengau
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | husavik
# Processing Record 9 of Set 3 | benin
# Processing Record 10 of Set 3 | semporna
# Processing Record 11 of Set 3 | usvyaty
# Processing Record 12 of Set 3 | corvallis
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | abiy adi
# City not found. Skipping...
# Processing Record 15 of Set 3 | souillac
# Processing Record 16 of Set 3 | dalvik
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | san patricio
# Processing Record 19 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 3 | hamilton
# Processing Record 21 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 3 | champerico
# Processing Record 23 of Set 3 | upernavik
# Processing Record 24 of Set 3 | alberton
# Processing Record 25 of Set 3 | chiman
# Processing Record 26 of Set 3 | san pedro
# Processing Record 27 of Set 3 | trojan
# Processing Record 28 of Set 3 | jalu
# Processing Record 29 of Set 3 | tigil
# Processing Record 30 of Set 3 | ulladulla
# Processing Record 31 of Set 3 | coquimbo
# Processing Record 32 of Set 3 | kant
# Processing Record 33 of Set 3 | evensk
# Processing Record 34 of Set 3 | stornoway
# Processing Record 35 of Set 3 | estevan
# Processing Record 36 of Set 3 | saint-philippe
# Processing Record 37 of Set 3 | miramar
# Processing Record 38 of Set 3 | sayan
# Processing Record 39 of Set 3 | nalut
# Processing Record 40 of Set 3 | new norfolk
# Processing Record 41 of Set 3 | ponta do sol
# Processing Record 42 of Set 3 | tautira
# Processing Record 43 of Set 3 | jambi
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | east wenatchee bench
# Processing Record 46 of Set 3 | merke
# Processing Record 47 of Set 3 | port hardy
# Processing Record 48 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 3 | san carlos
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | carutapera
# Processing Record 2 of Set 4 | takoradi
# Processing Record 3 of Set 4 | tasiilaq
# Processing Record 4 of Set 4 | sayyan
# Processing Record 5 of Set 4 | nikolskoye
# Processing Record 6 of Set 4 | lubao
# Processing Record 7 of Set 4 | vardo
# Processing Record 8 of Set 4 | sur
# Processing Record 9 of Set 4 | shingu
# Processing Record 10 of Set 4 | rosita
# Processing Record 11 of Set 4 | saskylakh
# Processing Record 12 of Set 4 | serebryanyy bor
# Processing Record 13 of Set 4 | iqaluit
# Processing Record 14 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 4 | lucea
# Processing Record 16 of Set 4 | tuatapere
# Processing Record 17 of Set 4 | srednekolymsk
# Processing Record 18 of Set 4 | oshawa
# Processing Record 19 of Set 4 | sistranda
# Processing Record 20 of Set 4 | avarua
# Processing Record 21 of Set 4 | bengkulu
# Processing Record 22 of Set 4 | tighina
# Processing Record 23 of Set 4 | leh
# Processing Record 24 of Set 4 | codrington
# Processing Record 25 of Set 4 | kuytun
# Processing Record 26 of Set 4 | tecoanapa
# Processing Record 27 of Set 4 | virginia beach
# Processing Record 28 of Set 4 | asau
# Processing Record 29 of Set 4 | banjar
# Processing Record 30 of Set 4 | ust-tsilma
# Processing Record 31 of Set 4 | vanimo
# Processing Record 32 of Set 4 | dakar
# Processing Record 33 of Set 4 | dikson
# Processing Record 34 of Set 4 | sitka
# Processing Record 35 of Set 4 | mahebourg
# Processing Record 36 of Set 4 | longyearbyen
# Processing Record 37 of Set 4 | berbera
# Processing Record 38 of Set 4 | temnikov
# Processing Record 39 of Set 4 | kruisfontein
# Processing Record 40 of Set 4 | vysokogornyy
# Processing Record 41 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 4 | sao jose da coroa grande
# Processing Record 43 of Set 4 | ostersund
# Processing Record 44 of Set 4 | mujiayingzi
# Processing Record 45 of Set 4 | coruripe
# Processing Record 46 of Set 4 | pataskala
# Processing Record 47 of Set 4 | hay river
# Processing Record 48 of Set 4 | awbari
# Processing Record 49 of Set 4 | tabou
# Processing Record 50 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 1 of Set 5 | maldonado
# Processing Record 2 of Set 5 | kirakira
# Processing Record 3 of Set 5 | penzance
# Processing Record 4 of Set 5 | kieta
# Processing Record 5 of Set 5 | yar-sale
# Processing Record 6 of Set 5 | vila velha
# Processing Record 7 of Set 5 | haines junction
# Processing Record 8 of Set 5 | gorontalo
# Processing Record 9 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 5 | ilulissat
# Processing Record 11 of Set 5 | hami
# Processing Record 12 of Set 5 | road town
# Processing Record 13 of Set 5 | mayo
# Processing Record 14 of Set 5 | komsomolskiy
# Processing Record 15 of Set 5 | cockburn town
# Processing Record 16 of Set 5 | xapuri
# Processing Record 17 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 18 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 5 | kodinsk
# Processing Record 20 of Set 5 | yangjiang
# Processing Record 21 of Set 5 | lebu
# Processing Record 22 of Set 5 | leningradskiy
# Processing Record 23 of Set 5 | dunedin
# Processing Record 24 of Set 5 | warrnambool
# Processing Record 25 of Set 5 | lavrentiya
# Processing Record 26 of Set 5 | kysyl-syr
# Processing Record 27 of Set 5 | kaitangata
# Processing Record 28 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 5 | dali
# Processing Record 31 of Set 5 | egvekinot
# Processing Record 32 of Set 5 | korla
# Processing Record 33 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 5 | caibarien
# Processing Record 35 of Set 5 | gweta
# Processing Record 36 of Set 5 | umm ruwabah
# City not found. Skipping...
# Processing Record 37 of Set 5 | moerai
# Processing Record 38 of Set 5 | ayagoz
# Processing Record 39 of Set 5 | san quintin
# Processing Record 40 of Set 5 | quatre cocos
# Processing Record 41 of Set 5 | ulaangom
# Processing Record 42 of Set 5 | carmen
# Processing Record 43 of Set 5 | lobva
# Processing Record 44 of Set 5 | lata
# Processing Record 45 of Set 5 | christchurch
# Processing Record 46 of Set 5 | baykit
# Processing Record 47 of Set 5 | cap malheureux
# Processing Record 48 of Set 5 | jinchang
# Processing Record 49 of Set 5 | richards bay
# Processing Record 50 of Set 5 | coihaique
# Processing Record 1 of Set 6 | nacala
# Processing Record 2 of Set 6 | porkhov
# Processing Record 3 of Set 6 | reconquista
# Processing Record 4 of Set 6 | spermezeu
# Processing Record 5 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 6 | matara
# Processing Record 7 of Set 6 | usinsk
# Processing Record 8 of Set 6 | dingle
# Processing Record 9 of Set 6 | marrakesh
# Processing Record 10 of Set 6 | karratha
# Processing Record 11 of Set 6 | qasigiannguit
# Processing Record 12 of Set 6 | vila franca do campo
# Processing Record 13 of Set 6 | saint-joseph
# Processing Record 14 of Set 6 | mapiripan
# Processing Record 15 of Set 6 | caceres
# Processing Record 16 of Set 6 | falam
# Processing Record 17 of Set 6 | kirovskiy
# Processing Record 18 of Set 6 | gamba
# Processing Record 19 of Set 6 | aden
# Processing Record 20 of Set 6 | sampit
# Processing Record 21 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 6 | abha
# Processing Record 23 of Set 6 | cabuyaro
# Processing Record 24 of Set 6 | erin
# Processing Record 25 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 26 of Set 6 | rosarito
# Processing Record 27 of Set 6 | cayenne
# Processing Record 28 of Set 6 | isangel
# Processing Record 29 of Set 6 | luganville
# Processing Record 30 of Set 6 | vestmannaeyjar
# Processing Record 31 of Set 6 | shache
# Processing Record 32 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 6 | northam
# Processing Record 34 of Set 6 | guerrero negro
# Processing Record 35 of Set 6 | tyazhinskiy
# Processing Record 36 of Set 6 | posse
# Processing Record 37 of Set 6 | kunszentmarton
# Processing Record 38 of Set 6 | praia
# Processing Record 39 of Set 6 | batangafo
# Processing Record 40 of Set 6 | nizhniy chir
# Processing Record 41 of Set 6 | huilong
# Processing Record 42 of Set 6 | antofagasta
# Processing Record 43 of Set 6 | iskateley
# Processing Record 44 of Set 6 | puerto baquerizo moreno
# Processing Record 45 of Set 6 | arman
# Processing Record 46 of Set 6 | kokstad
# Processing Record 47 of Set 6 | saint anthony
# Processing Record 48 of Set 6 | solnechnyy
# Processing Record 49 of Set 6 | sao joao da barra
# Processing Record 50 of Set 6 | mount gambier
# Processing Record 1 of Set 7 | devonport
# Processing Record 2 of Set 7 | grindavik
# Processing Record 3 of Set 7 | olafsvik
# Processing Record 4 of Set 7 | ponta delgada
# Processing Record 5 of Set 7 | flin flon
# Processing Record 6 of Set 7 | eston
# Processing Record 7 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 7 | hovd
# Processing Record 9 of Set 7 | grimshaw
# Processing Record 10 of Set 7 | whitehorse
# Processing Record 11 of Set 7 | fare
# Processing Record 12 of Set 7 | freetown
# Processing Record 13 of Set 7 | shirokiy
# Processing Record 14 of Set 7 | nome
# Processing Record 15 of Set 7 | ostrovnoy
# Processing Record 16 of Set 7 | saldanha
# Processing Record 17 of Set 7 | najran
# Processing Record 18 of Set 7 | bandarbeyla
# Processing Record 19 of Set 7 | tura
# Processing Record 20 of Set 7 | moree
# Processing Record 21 of Set 7 | ipswich
# Processing Record 22 of Set 7 | hauterive
# Processing Record 23 of Set 7 | yaan
# Processing Record 24 of Set 7 | bambous virieux
# Processing Record 25 of Set 7 | sioux lookout
# Processing Record 26 of Set 7 | soyo
# Processing Record 27 of Set 7 | barlinek
# Processing Record 28 of Set 7 | azuaga
# Processing Record 29 of Set 7 | cabo san lucas
# Processing Record 30 of Set 7 | tsiroanomandidy
# Processing Record 31 of Set 7 | shahrud
# Processing Record 32 of Set 7 | port hedland
# Processing Record 33 of Set 7 | hambantota
# Processing Record 34 of Set 7 | moindou
# Processing Record 35 of Set 7 | te anau
# Processing Record 36 of Set 7 | verkhnevilyuysk
# Processing Record 37 of Set 7 | hualmay
# Processing Record 38 of Set 7 | tuktoyaktuk
# Processing Record 39 of Set 7 | severnoye
# Processing Record 40 of Set 7 | sorong
# Processing Record 41 of Set 7 | bontang
# Processing Record 42 of Set 7 | nuristan
# Processing Record 43 of Set 7 | mazatan
# Processing Record 44 of Set 7 | katobu
# Processing Record 45 of Set 7 | grand gaube
# Processing Record 46 of Set 7 | bathsheba
# Processing Record 47 of Set 7 | araouane
# Processing Record 48 of Set 7 | rio grande
# Processing Record 49 of Set 7 | palmer
# Processing Record 50 of Set 7 | portland
# Processing Record 1 of Set 8 | adwa
# Processing Record 2 of Set 8 | chapais
# Processing Record 3 of Set 8 | monroe
# Processing Record 4 of Set 8 | peniche
# Processing Record 5 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | tiarei
# Processing Record 8 of Set 8 | ngama
# Processing Record 9 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 8 | dekar
# Processing Record 12 of Set 8 | fairbanks
# Processing Record 13 of Set 8 | okhotsk
# Processing Record 14 of Set 8 | leshukonskoye
# Processing Record 15 of Set 8 | faya
# Processing Record 16 of Set 8 | san juan
# Processing Record 17 of Set 8 | suozhen
# Processing Record 18 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 8 | birjand
# Processing Record 20 of Set 8 | foam lake
# Processing Record 21 of Set 8 | marsh harbour
# Processing Record 22 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 8 | qibili
# City not found. Skipping...
# Processing Record 24 of Set 8 | nantucket
# Processing Record 25 of Set 8 | tilichiki
# Processing Record 26 of Set 8 | pinotepa nacional
# Processing Record 27 of Set 8 | wasilla
# Processing Record 28 of Set 8 | kostinbrod
# Processing Record 29 of Set 8 | zhigansk
# Processing Record 30 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 8 | bishop auckland
# Processing Record 32 of Set 8 | muroto
# Processing Record 33 of Set 8 | mitu
# Processing Record 34 of Set 8 | vilhena
# Processing Record 35 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 36 of Set 8 | talmaciu
# City not found. Skipping...
# Processing Record 37 of Set 8 | magistralnyy
# Processing Record 38 of Set 8 | poya
# Processing Record 39 of Set 8 | sirnak
# Processing Record 40 of Set 8 | boende
# Processing Record 41 of Set 8 | sladkovo
# Processing Record 42 of Set 8 | dubbo
# Processing Record 43 of Set 8 | eureka
# Processing Record 44 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 8 | haimen
# Processing Record 46 of Set 8 | canora
# Processing Record 47 of Set 8 | trofors
# Processing Record 48 of Set 8 | tsabong
# Processing Record 49 of Set 8 | denham springs
# Processing Record 50 of Set 8 | beyneu
# Processing Record 1 of Set 9 | riyadh
# Processing Record 2 of Set 9 | merauke
# Processing Record 3 of Set 9 | luderitz
# Processing Record 4 of Set 9 | nkhata bay
# Processing Record 5 of Set 9 | prince rupert
# Processing Record 6 of Set 9 | ballina
# Processing Record 7 of Set 9 | sagarejo
# Processing Record 8 of Set 9 | maple creek
# Processing Record 9 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 9 | asosa
# Processing Record 11 of Set 9 | chara
# Processing Record 12 of Set 9 | kaeo
# Processing Record 13 of Set 9 | krasnoborsk
# Processing Record 14 of Set 9 | inhambane
# Processing Record 15 of Set 9 | saint-georges
# Processing Record 16 of Set 9 | saint-augustin
# Processing Record 17 of Set 9 | grabovo
# Processing Record 18 of Set 9 | meulaboh
# Processing Record 19 of Set 9 | jumla
# Processing Record 20 of Set 9 | rio verde de mato grosso
# Processing Record 21 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 22 of Set 9 | walvis bay
# Processing Record 23 of Set 9 | adrar
# Processing Record 24 of Set 9 | mount isa
# Processing Record 25 of Set 9 | hobyo
# Processing Record 26 of Set 9 | mafinga
# Processing Record 27 of Set 9 | guantanamo
# Processing Record 28 of Set 9 | clyde river
# Processing Record 29 of Set 9 | pamantingan
# Processing Record 30 of Set 9 | sandwick
# Processing Record 31 of Set 9 | sao luis de montes belos
# Processing Record 32 of Set 9 | sondrio
# Processing Record 33 of Set 9 | adelaide
# Processing Record 34 of Set 9 | chengmai
# City not found. Skipping...
# Processing Record 35 of Set 9 | kenai
# Processing Record 36 of Set 9 | erode
# Processing Record 37 of Set 9 | wukari
# Processing Record 38 of Set 9 | myitkyina
# Processing Record 39 of Set 9 | nikolayevka
# Processing Record 40 of Set 9 | salmon arm
# Processing Record 41 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 9 | sisimiut
# Processing Record 43 of Set 9 | bardiyah
# Processing Record 44 of Set 9 | mogochin
# City not found. Skipping...
# Processing Record 45 of Set 9 | ipixuna
# Processing Record 46 of Set 9 | plettenberg bay
# Processing Record 47 of Set 9 | tucumcari
# Processing Record 48 of Set 9 | erenhot
# Processing Record 49 of Set 9 | berlevag
# Processing Record 50 of Set 9 | el alto
# Processing Record 1 of Set 10 | laylay
# Processing Record 2 of Set 10 | celestun
# Processing Record 3 of Set 10 | morant bay
# Processing Record 4 of Set 10 | teguldet
# Processing Record 5 of Set 10 | afsin
# Processing Record 6 of Set 10 | bilma
# Processing Record 7 of Set 10 | hermosillo
# Processing Record 8 of Set 10 | pala
# Processing Record 9 of Set 10 | alugan
# Processing Record 10 of Set 10 | akyab
# Processing Record 11 of Set 10 | sorland
# Processing Record 12 of Set 10 | lerwick
# Processing Record 13 of Set 10 | pasco
# Processing Record 14 of Set 10 | paragominas
# Processing Record 15 of Set 10 | moron
# Processing Record 16 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 17 of Set 10 | laguna
# Processing Record 18 of Set 10 | mahon
# Processing Record 19 of Set 10 | palauig
# Processing Record 20 of Set 10 | rolleston
# Processing Record 21 of Set 10 | nouadhibou
# Processing Record 22 of Set 10 | bankfoot
# Processing Record 23 of Set 10 | makasar
# Processing Record 24 of Set 10 | lancaster
# Processing Record 25 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 26 of Set 10 | otane
# Processing Record 27 of Set 10 | vestmanna
# Processing Record 28 of Set 10 | kalmunai
# Processing Record 29 of Set 10 | banfora
# Processing Record 30 of Set 10 | sinnamary
# Processing Record 31 of Set 10 | aripuana
# Processing Record 32 of Set 10 | am timan
# Processing Record 33 of Set 10 | nautla
# Processing Record 34 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 10 | ukhta
# Processing Record 36 of Set 10 | malishka
# Processing Record 37 of Set 10 | noyabrsk
# Processing Record 38 of Set 10 | marabba
# Processing Record 39 of Set 10 | nemuro
# Processing Record 40 of Set 10 | svetlyy
# Processing Record 41 of Set 10 | ngunguru
# Processing Record 42 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 43 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 10 | itoman
# Processing Record 45 of Set 10 | roebourne
# Processing Record 46 of Set 10 | issia
# Processing Record 47 of Set 10 | vila
# Processing Record 48 of Set 10 | sapa
# Processing Record 49 of Set 10 | oranjestad
# Processing Record 50 of Set 10 | buraydah
# Processing Record 1 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 11 | samarai
# Processing Record 3 of Set 11 | veinticinco de mayo
# Processing Record 4 of Set 11 | shimoda
# Processing Record 5 of Set 11 | bilibino
# Processing Record 6 of Set 11 | kralendijk
# Processing Record 7 of Set 11 | sambava
# Processing Record 8 of Set 11 | kailua
# Processing Record 9 of Set 11 | goderich
# Processing Record 10 of Set 11 | kutum
# Processing Record 11 of Set 11 | mayumba
# Processing Record 12 of Set 11 | timizart
# Processing Record 13 of Set 11 | muborak
# Processing Record 14 of Set 11 | caravelas
# Processing Record 15 of Set 11 | eirunepe
# Processing Record 16 of Set 11 | turukhansk
# Processing Record 17 of Set 11 | roswell
# Processing Record 18 of Set 11 | huarmey
# Processing Record 19 of Set 11 | acapulco
# Processing Record 20 of Set 11 | santo antonio do ica
# Processing Record 21 of Set 11 | punto fijo
# Processing Record 22 of Set 11 | labuhan
# Processing Record 23 of Set 11 | mareeba
# Processing Record 24 of Set 11 | elko
# Processing Record 25 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 11 | aljezur
# Processing Record 27 of Set 11 | muros
# Processing Record 28 of Set 11 | ushumun
# Processing Record 29 of Set 11 | trairi
# Processing Record 30 of Set 11 | ozernovskiy
# Processing Record 31 of Set 11 | avera
# Processing Record 32 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 11 | poum
# Processing Record 34 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 11 | baihar
# Processing Record 36 of Set 11 | mindelo
# Processing Record 37 of Set 11 | aykhal
# Processing Record 38 of Set 11 | koutiala
# Processing Record 39 of Set 11 | gimli
# Processing Record 40 of Set 11 | log
# Processing Record 41 of Set 11 | mali
# Processing Record 42 of Set 11 | beringovskiy
# Processing Record 43 of Set 11 | goianesia
# Processing Record 44 of Set 11 | lethem
# Processing Record 45 of Set 11 | mitchell
# Processing Record 46 of Set 11 | kamaishi
# Processing Record 47 of Set 11 | sochi
# Processing Record 48 of Set 11 | san cristobal
# Processing Record 49 of Set 11 | point pleasant
# Processing Record 50 of Set 11 | plainview
# Processing Record 1 of Set 12 | chengde
# Processing Record 2 of Set 12 | ko samui
# Processing Record 3 of Set 12 | bayburt
# Processing Record 4 of Set 12 | west wendover
# Processing Record 5 of Set 12 | atar
# Processing Record 6 of Set 12 | nanakuli
# Processing Record 7 of Set 12 | waw
# Processing Record 8 of Set 12 | havoysund
# Processing Record 9 of Set 12 | ternate
# Processing Record 10 of Set 12 | itarema
# Processing Record 11 of Set 12 | dezhou
# Processing Record 12 of Set 12 | aasiaat
# Processing Record 13 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 14 of Set 12 | windsor
# Processing Record 15 of Set 12 | pervomayskiy
# Processing Record 16 of Set 12 | srivardhan
# Processing Record 17 of Set 12 | kadaya
# Processing Record 18 of Set 12 | geraldton
# Processing Record 19 of Set 12 | high level
# Processing Record 20 of Set 12 | kristiansund
# Processing Record 21 of Set 12 | mao
# Processing Record 22 of Set 12 | margate
# Processing Record 23 of Set 12 | kletskaya
# Processing Record 24 of Set 12 | hamada
# Processing Record 25 of Set 12 | comodoro rivadavia
# Processing Record 26 of Set 12 | nampula
# Processing Record 27 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 12 | omboue
# Processing Record 29 of Set 12 | bela
# Processing Record 30 of Set 12 | alice springs
# Processing Record 31 of Set 12 | yablonovo
# Processing Record 32 of Set 12 | basoko
# Processing Record 33 of Set 12 | jiuquan
# Processing Record 34 of Set 12 | kangavar
# Processing Record 35 of Set 12 | aklavik
# Processing Record 36 of Set 12 | maracacume
# Processing Record 37 of Set 12 | puerto lempira
# Processing Record 38 of Set 12 | bumba
# Processing Record 39 of Set 12 | palomares
# Processing Record 40 of Set 12 | beni
# Processing Record 41 of Set 12 | hofn
# Processing Record 42 of Set 12 | huanren
# Processing Record 43 of Set 12 | esperance
# Processing Record 44 of Set 12 | jibuti
# Processing Record 45 of Set 12 | olinda
# Processing Record 46 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 12 | siderno
# Processing Record 48 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 12 | waynesville
# Processing Record 50 of Set 12 | santarem
# Processing Record 1 of Set 13 | ambulu
# Processing Record 2 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 3 of Set 13 | kitimat
# Processing Record 4 of Set 13 | anadyr
# Processing Record 5 of Set 13 | maragogi
# Processing Record 6 of Set 13 | stade
# Processing Record 7 of Set 13 | la macarena
# Processing Record 8 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 13 | myingyan
# Processing Record 10 of Set 13 | taoudenni
# Processing Record 11 of Set 13 | san carlos de bariloche
# Processing Record 12 of Set 13 | aswan
# Processing Record 13 of Set 13 | makakilo city
# Processing Record 14 of Set 13 | abai
# Processing Record 15 of Set 13 | gaziantep
# Processing Record 16 of Set 13 | ust-uda
# Processing Record 17 of Set 13 | kloulklubed
# Processing Record 18 of Set 13 | pasighat
# Processing Record 19 of Set 13 | praia da vitoria
# Processing Record 20 of Set 13 | tottori
# Processing Record 21 of Set 13 | gat
# Processing Record 22 of Set 13 | namatanai
# Processing Record 23 of Set 13 | cabra
# Processing Record 24 of Set 13 | general roca
# Processing Record 25 of Set 13 | toora-khem
# Processing Record 26 of Set 13 | zhongshu
# Processing Record 27 of Set 13 | kenora
# Processing Record 28 of Set 13 | wattegama
# Processing Record 29 of Set 13 | aborlan
# Processing Record 30 of Set 13 | safranbolu
# Processing Record 31 of Set 13 | victor harbor
# Processing Record 32 of Set 13 | wanlaweyn
# Processing Record 33 of Set 13 | ambon
# Processing Record 34 of Set 13 | sao miguel do araguaia
# Processing Record 35 of Set 13 | wielun
# Processing Record 36 of Set 13 | khandbari
# Processing Record 37 of Set 13 | oktyabrskiy
# Processing Record 38 of Set 13 | umm lajj
# Processing Record 39 of Set 13 | staraya russa
# Processing Record 40 of Set 13 | itiuba
# Processing Record 41 of Set 13 | astaneh-ye ashrafiyeh
# Processing Record 42 of Set 13 | ledyard
# Processing Record 43 of Set 13 | cuxhaven
# Processing Record 44 of Set 13 | odesskoye
# Processing Record 45 of Set 13 | malartic
# Processing Record 46 of Set 13 | troitskoye
# Processing Record 47 of Set 13 | baruun-urt
# Processing Record 48 of Set 13 | flinders
# Processing Record 49 of Set 13 | abnub
# Processing Record 50 of Set 13 | sarangani
# Processing Record 1 of Set 14 | camana
# Processing Record 2 of Set 14 | tweed
# Processing Record 3 of Set 14 | half moon bay
# Processing Record 4 of Set 14 | kattivakkam
# Processing Record 5 of Set 14 | blagoyevo
# Processing Record 6 of Set 14 | saint-pierre
# Processing Record 7 of Set 14 | lavumisa
# Processing Record 8 of Set 14 | nago
# Processing Record 9 of Set 14 | adre
# Processing Record 10 of Set 14 | port moresby
# Processing Record 11 of Set 14 | pontes e lacerda
# Processing Record 12 of Set 14 | klaksvik
# Processing Record 13 of Set 14 | diffa
# Processing Record 14 of Set 14 | lompoc
# Processing Record 15 of Set 14 | kovur
# Processing Record 16 of Set 14 | kaukauna
# Processing Record 17 of Set 14 | port washington
# Processing Record 18 of Set 14 | kawalu
# Processing Record 19 of Set 14 | takahashi
# Processing Record 20 of Set 14 | puerto el triunfo
# Processing Record 21 of Set 14 | caraguatatuba
# Processing Record 22 of Set 14 | dudinka
# Processing Record 23 of Set 14 | kwinana
# Processing Record 24 of Set 14 | seoul
# Processing Record 25 of Set 14 | jefferson city
# Processing Record 26 of Set 14 | ossora
# Processing Record 27 of Set 14 | camopi
# Processing Record 28 of Set 14 | san policarpo
# Processing Record 29 of Set 14 | manokwari
# Processing Record 30 of Set 14 | pitimbu
# Processing Record 31 of Set 14 | torbay
# Processing Record 32 of Set 14 | teguise
# Processing Record 33 of Set 14 | upata
# Processing Record 34 of Set 14 | takab
# Processing Record 35 of Set 14 | sechura
# Processing Record 36 of Set 14 | soe
# Processing Record 37 of Set 14 | port blair
# Processing Record 38 of Set 14 | la palma
# Processing Record 39 of Set 14 | ormond beach
# Processing Record 40 of Set 14 | sayansk
# Processing Record 41 of Set 14 | tayoltita
# Processing Record 42 of Set 14 | the valley
# Processing Record 43 of Set 14 | wajir
# Processing Record 44 of Set 14 | puerto gaitan
# Processing Record 45 of Set 14 | makinsk
# Processing Record 46 of Set 14 | gambela
# Processing Record 47 of Set 14 | rawson
# Processing Record 48 of Set 14 | juba
# Processing Record 49 of Set 14 | la ronge
# Processing Record 50 of Set 14 | naziya
# Processing Record 1 of Set 15 | nevel
# Processing Record 2 of Set 15 | kirove
# Processing Record 3 of Set 15 | mariental
# Processing Record 4 of Set 15 | phayao
# Processing Record 5 of Set 15 | buta
# Processing Record 6 of Set 15 | nisia floresta
# Processing Record 7 of Set 15 | kotra
# Processing Record 8 of Set 15 | arlit
# Processing Record 9 of Set 15 | isiro
# Processing Record 10 of Set 15 | selizharovo
# Processing Record 11 of Set 15 | tagusao
# Processing Record 12 of Set 15 | uige
# Processing Record 13 of Set 15 | sibolga
# Processing Record 14 of Set 15 | prabumulih
# Processing Record 15 of Set 15 | grand-santi
# Processing Record 16 of Set 15 | dymer
# Processing Record 17 of Set 15 | daura
# Processing Record 18 of Set 15 | bundaberg
# Processing Record 19 of Set 15 | yatou
# Processing Record 20 of Set 15 | nelson bay
# Processing Record 21 of Set 15 | atagay
# Processing Record 22 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 15 | tosya
# Processing Record 24 of Set 15 | helmsdale
# Processing Record 25 of Set 15 | cleveland
# Processing Record 26 of Set 15 | little current
# Processing Record 27 of Set 15 | mizdah
# Processing Record 28 of Set 15 | borodino
# Processing Record 29 of Set 15 | vanderhoof
# Processing Record 30 of Set 15 | hellvik
# Processing Record 31 of Set 15 | belfast
# Processing Record 32 of Set 15 | torrijos
# Processing Record 33 of Set 15 | batie
# Processing Record 34 of Set 15 | garmsar
# Processing Record 35 of Set 15 | sao desiderio
# Processing Record 36 of Set 15 | punta gorda
# Processing Record 37 of Set 15 | taltal
# Processing Record 38 of Set 15 | chalons-en-champagne
# Processing Record 39 of Set 15 | kisaran
# Processing Record 40 of Set 15 | sulangan
# Processing Record 41 of Set 15 | veseloyarsk
# Processing Record 42 of Set 15 | mutsu
# Processing Record 43 of Set 15 | odweyne
# Processing Record 44 of Set 15 | inuvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Antibes      FR  43.5624    7.1278     57.67        79           0
# 1      Mirnyy      RU  62.5353  113.9611     -6.77        83         100
# 2      Kodiak      US  57.7900 -152.4072     42.31       100         100
# 3     Kahului      US  20.8947 -156.4700     82.42        62          20
# 4    Hermanus      ZA -34.4187   19.2345     56.80        71          93
# 5     Kavieng      PG  -2.5744  150.7967     83.01        70         100
# 6  Georgetown      MY   5.4112  100.3354     80.24        93          20
# 7       Airai      TL  -8.9266  125.4092     62.82        85         100
# 8   Jamestown      US  42.0970  -79.2353     35.19        73         100
# 9       Pevek      RU  69.7008  170.3133      7.03        95         100
#
#    Wind Speed Current Description
# 0        5.75           clear sky
# 1        1.99     overcast clouds
# 2       14.97       moderate rain
# 3       20.71          few clouds
# 4        3.89     overcast clouds
# 5        9.06     overcast clouds
# 6        2.30          few clouds
# 7        0.67     overcast clouds
# 8       12.66          light snow
# 9        1.01          light snow

# %%
# Create the output file (CSV).
output_data_file = ("../Weather_Database/WeatherPy_Challenge.csv")
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
